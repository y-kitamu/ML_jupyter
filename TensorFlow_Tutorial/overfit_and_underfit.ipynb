# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.0.0

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import multiprocessing as mp

import pathlib
import shutil
import tempfile

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequence(sequences, dimension):
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0
    return results

# %%
train_data = multi_hot_sequence(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequence(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
def train_basemodel():
    baseline_model = keras.Sequential([
        keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
        keras.layers.Dense(16, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    baseline_model.compile(optimizer='adam',
                           loss='binary_crossentropy',
                           metrics=['accuracy', 'binary_crossentropy'])
    baseline_model.summary()

    baseline_history = baseline_model.fit(train_data,
                                          train_labels,
                                          epochs=20,
                                          batch_size=512,
                                          validation_data=(test_data, test_labels),
                                          verbose=2)
    return baseline_history

# %%
with mp.Pool() as pool:
    baseline_history = pool.apply_async(train_basemodel)
    pool.close()
    pool.join()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.3620 - accuracy: 0.8525 - binary_crossentropy: 0.3620 - val_loss: 0.2928 - val_accuracy: 0.8828 - val_binary_crossentropy: 0.2928
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.1913 - accuracy: 0.9285 - binary_crossentropy: 0.1913 - val_loss: 0.3167 - val_accuracy: 0.8771 - val_binary_crossentropy: 0.3167
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.1430 - accuracy: 0.9479 - binary_crossentropy: 0.1430 - val_loss: 0.3528 - val_accuracy: 0.8709 - val_binary_crossentropy: 0.3528
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.1091 - accuracy: 0.9604 - binary_crossentropy: 0.1091 - val_loss: 0.4136 - val_accuracy: 0.8644 - val_binary_crossentropy: 0.4136
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.0799 - accuracy: 0.9721 - binary_crossentropy: 0.0799 - val_loss: 0.4835 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.4835
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.0593 - accuracy: 0.9799 - binary_crossentropy: 0.0593 - val_loss: 0.5509 - val_accuracy: 0.8530 - val_binary_crossentropy: 0.5509
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.0436 - accuracy: 0.9860 - binary_crossentropy: 0.0436 - val_loss: 0.6123 - val_accuracy: 0.8528 - val_binary_crossentropy: 0.6123
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.0316 - accuracy: 0.9899 - binary_crossentropy: 0.0316 - val_loss: 0.6929 - val_accuracy: 0.8533 - val_binary_crossentropy: 0.6929
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.0224 - accuracy: 0.9935 - binary_crossentropy: 0.0224 - val_loss: 0.7775 - val_accuracy: 0.8522 - val_binary_crossentropy: 0.7775
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.0176 - accuracy: 0.9950 - binary_crossentropy: 0.0176 - val_loss: 0.8549 - val_accuracy: 0.8488 - val_binary_crossentropy: 0.8549
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.0132 - accuracy: 0.9962 - binary_crossentropy: 0.0132 - val_loss: 0.8979 - val_accuracy: 0.8527 - val_binary_crossentropy: 0.8979
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.0080 - accuracy: 0.9982 - binary_crossentropy: 0.0080 - val_loss: 0.9807 - val_accuracy: 0.8507 - val_binary_crossentropy: 0.9807
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.0078 - accuracy: 0.9979 - binary_crossentropy: 0.0078 - val_loss: 1.0077 - val_accuracy: 0.8528 - val_binary_crossentropy: 1.0077
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0056 - accuracy: 0.9988 - binary_crossentropy: 0.0056 - val_loss: 1.0797 - val_accuracy: 0.8498 - val_binary_crossentropy: 1.0797
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0053 - accuracy: 0.9988 - binary_crossentropy: 0.0053 - val_loss: 1.1372 - val_accuracy: 0.8478 - val_binary_crossentropy: 1.1372
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0121 - accuracy: 0.9963 - binary_crossentropy: 0.0121 - val_loss: 1.0958 - val_accuracy: 0.8466 - val_binary_crossentropy: 1.0958
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0171 - accuracy: 0.9946 - binary_crossentropy: 0.0171 - val_loss: 1.1207 - val_accuracy: 0.8454 - val_binary_crossentropy: 1.1207
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0145 - accuracy: 0.9944 - binary_crossentropy: 0.0145 - val_loss: 1.0639 - val_accuracy: 0.8462 - val_binary_crossentropy: 1.0639
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0091 - accuracy: 0.9972 - binary_crossentropy: 0.0091 - val_loss: 1.1739 - val_accuracy: 0.8502 - val_binary_crossentropy: 1.1739
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0029 - accuracy: 0.9995 - binary_crossentropy: 0.0029 - val_loss: 1.2266 - val_accuracy: 0.8486 - val_binary_crossentropy: 1.2266

# %%
baseline_history = train_basemodel()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.5886 - accuracy: 0.6344 - binary_crossentropy: 0.5886 - val_loss: 0.5068 - val_accuracy: 0.8197 - val_binary_crossentropy: 0.5068
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.3993 - accuracy: 0.8882 - binary_crossentropy: 0.3993 - val_loss: 0.3434 - val_accuracy: 0.8844 - val_binary_crossentropy: 0.3434
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.2288 - accuracy: 0.9302 - binary_crossentropy: 0.2288 - val_loss: 0.2917 - val_accuracy: 0.8864 - val_binary_crossentropy: 0.2917
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.1592 - accuracy: 0.9482 - binary_crossentropy: 0.1592 - val_loss: 0.3062 - val_accuracy: 0.8814 - val_binary_crossentropy: 0.3062
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.1214 - accuracy: 0.9623 - binary_crossentropy: 0.1214 - val_loss: 0.3286 - val_accuracy: 0.8764 - val_binary_crossentropy: 0.3286
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.0917 - accuracy: 0.9744 - binary_crossentropy: 0.0917 - val_loss: 0.3569 - val_accuracy: 0.8735 - val_binary_crossentropy: 0.3569
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.0678 - accuracy: 0.9839 - binary_crossentropy: 0.0678 - val_loss: 0.3928 - val_accuracy: 0.8710 - val_binary_crossentropy: 0.3928
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.0495 - accuracy: 0.9906 - binary_crossentropy: 0.0495 - val_loss: 0.4237 - val_accuracy: 0.8685 - val_binary_crossentropy: 0.4237
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.0345 - accuracy: 0.9943 - binary_crossentropy: 0.0345 - val_loss: 0.4622 - val_accuracy: 0.8668 - val_binary_crossentropy: 0.4622
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.0245 - accuracy: 0.9968 - binary_crossentropy: 0.0245 - val_loss: 0.4954 - val_accuracy: 0.8659 - val_binary_crossentropy: 0.4954
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.0175 - accuracy: 0.9981 - binary_crossentropy: 0.0175 - val_loss: 0.5251 - val_accuracy: 0.8637 - val_binary_crossentropy: 0.5251
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.0129 - accuracy: 0.9989 - binary_crossentropy: 0.0129 - val_loss: 0.5602 - val_accuracy: 0.8634 - val_binary_crossentropy: 0.5602
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.0099 - accuracy: 0.9991 - binary_crossentropy: 0.0099 - val_loss: 0.5821 - val_accuracy: 0.8622 - val_binary_crossentropy: 0.5821
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0077 - accuracy: 0.9993 - binary_crossentropy: 0.0077 - val_loss: 0.6067 - val_accuracy: 0.8631 - val_binary_crossentropy: 0.6067
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0062 - accuracy: 0.9994 - binary_crossentropy: 0.0062 - val_loss: 0.6264 - val_accuracy: 0.8617 - val_binary_crossentropy: 0.6264
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0050 - accuracy: 0.9996 - binary_crossentropy: 0.0050 - val_loss: 0.6417 - val_accuracy: 0.8611 - val_binary_crossentropy: 0.6417
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0040 - accuracy: 0.9996 - binary_crossentropy: 0.0040 - val_loss: 0.6624 - val_accuracy: 0.8617 - val_binary_crossentropy: 0.6624
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0032 - accuracy: 0.9997 - binary_crossentropy: 0.0032 - val_loss: 0.6797 - val_accuracy: 0.8617 - val_binary_crossentropy: 0.6797
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0026 - accuracy: 0.9998 - binary_crossentropy: 0.0026 - val_loss: 0.6953 - val_accuracy: 0.8618 - val_binary_crossentropy: 0.6953
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0022 - accuracy: 0.9998 - binary_crossentropy: 0.0022 - val_loss: 0.7088 - val_accuracy: 0.8618 - val_binary_crossentropy: 0.7088

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])
smaller_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smalle_history = smaller_model.fit(train_data, train_labels,
                                   epochs=20, batch_size=512, validation_data=(test_data, test_labels),
                                   verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.6307 - accuracy: 0.7364 - binary_crossentropy: 0.6307 - val_loss: 0.5433 - val_accuracy: 0.8370 - val_binary_crossentropy: 0.5433
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.4457 - accuracy: 0.8690 - binary_crossentropy: 0.4457 - val_loss: 0.4008 - val_accuracy: 0.8675 - val_binary_crossentropy: 0.4008
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.3268 - accuracy: 0.8969 - binary_crossentropy: 0.3268 - val_loss: 0.3342 - val_accuracy: 0.8804 - val_binary_crossentropy: 0.3342
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2631 - accuracy: 0.9146 - binary_crossentropy: 0.2631 - val_loss: 0.3022 - val_accuracy: 0.8871 - val_binary_crossentropy: 0.3022
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2240 - accuracy: 0.9263 - binary_crossentropy: 0.2240 - val_loss: 0.2882 - val_accuracy: 0.8878 - val_binary_crossentropy: 0.2882
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.1971 - accuracy: 0.9355 - binary_crossentropy: 0.1971 - val_loss: 0.2825 - val_accuracy: 0.8880 - val_binary_crossentropy: 0.2825
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.1764 - accuracy: 0.9432 - binary_crossentropy: 0.1764 - val_loss: 0.2833 - val_accuracy: 0.8862 - val_binary_crossentropy: 0.2833
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1593 - accuracy: 0.9477 - binary_crossentropy: 0.1593 - val_loss: 0.2861 - val_accuracy: 0.8850 - val_binary_crossentropy: 0.2861
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1454 - accuracy: 0.9531 - binary_crossentropy: 0.1454 - val_loss: 0.2927 - val_accuracy: 0.8839 - val_binary_crossentropy: 0.2927
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1332 - accuracy: 0.9580 - binary_crossentropy: 0.1332 - val_loss: 0.3004 - val_accuracy: 0.8822 - val_binary_crossentropy: 0.3004
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1229 - accuracy: 0.9624 - binary_crossentropy: 0.1229 - val_loss: 0.3107 - val_accuracy: 0.8794 - val_binary_crossentropy: 0.3107
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1134 - accuracy: 0.9659 - binary_crossentropy: 0.1134 - val_loss: 0.3208 - val_accuracy: 0.8785 - val_binary_crossentropy: 0.3208
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1046 - accuracy: 0.9688 - binary_crossentropy: 0.1046 - val_loss: 0.3325 - val_accuracy: 0.8764 - val_binary_crossentropy: 0.3325
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0971 - accuracy: 0.9719 - binary_crossentropy: 0.0971 - val_loss: 0.3462 - val_accuracy: 0.8733 - val_binary_crossentropy: 0.3462
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0903 - accuracy: 0.9750 - binary_crossentropy: 0.0903 - val_loss: 0.3621 - val_accuracy: 0.8706 - val_binary_crossentropy: 0.3621
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0837 - accuracy: 0.9773 - binary_crossentropy: 0.0837 - val_loss: 0.3713 - val_accuracy: 0.8713 - val_binary_crossentropy: 0.3713
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0777 - accuracy: 0.9795 - binary_crossentropy: 0.0777 - val_loss: 0.3858 - val_accuracy: 0.8698 - val_binary_crossentropy: 0.3858
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0721 - accuracy: 0.9821 - binary_crossentropy: 0.0721 - val_loss: 0.4020 - val_accuracy: 0.8675 - val_binary_crossentropy: 0.4020
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0668 - accuracy: 0.9842 - binary_crossentropy: 0.0668 - val_loss: 0.4170 - val_accuracy: 0.8663 - val_binary_crossentropy: 0.4170
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0619 - accuracy: 0.9860 - binary_crossentropy: 0.0619 - val_loss: 0.4331 - val_accuracy: 0.8651 - val_binary_crossentropy: 0.4331

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimzier='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy', 'binary_crossentropy'])
bigger_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 512)               5120512
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20, batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.4498 - accuracy: 0.7974 - binary_crossentropy: 0.4498 - val_loss: 0.2826 - val_accuracy: 0.8866 - val_binary_crossentropy: 0.2826
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.2135 - accuracy: 0.9156 - binary_crossentropy: 0.2135 - val_loss: 0.2771 - val_accuracy: 0.8869 - val_binary_crossentropy: 0.2771
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.1202 - accuracy: 0.9572 - binary_crossentropy: 0.1202 - val_loss: 0.6031 - val_accuracy: 0.8170 - val_binary_crossentropy: 0.6031
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.0643 - accuracy: 0.9810 - binary_crossentropy: 0.0643 - val_loss: 0.4372 - val_accuracy: 0.8821 - val_binary_crossentropy: 0.4372
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.0633 - accuracy: 0.9873 - binary_crossentropy: 0.0633 - val_loss: 0.4805 - val_accuracy: 0.8817 - val_binary_crossentropy: 0.4805
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.0439 - accuracy: 0.9942 - binary_crossentropy: 0.0439 - val_loss: 2.6216 - val_accuracy: 0.7010 - val_binary_crossentropy: 2.6216
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.0272 - accuracy: 0.9956 - binary_crossentropy: 0.0272 - val_loss: 0.6911 - val_accuracy: 0.8793 - val_binary_crossentropy: 0.6911
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.0911 - accuracy: 0.9901 - binary_crossentropy: 0.0911 - val_loss: 0.5858 - val_accuracy: 0.8737 - val_binary_crossentropy: 0.5858
# Epoch 9/20
# 25000/25000 - 2s - loss: 6.8242e-04 - accuracy: 1.0000 - binary_crossentropy: 6.8242e-04 - val_loss: 0.7496 - val_accuracy: 0.8781 - val_binary_crossentropy: 0.7496
# Epoch 10/20
# 25000/25000 - 2s - loss: 1.0250e-04 - accuracy: 1.0000 - binary_crossentropy: 1.0250e-04 - val_loss: 0.9209 - val_accuracy: 0.8782 - val_binary_crossentropy: 0.9209
# Epoch 11/20
# 25000/25000 - 2s - loss: 1.5174e-05 - accuracy: 1.0000 - binary_crossentropy: 1.5174e-05 - val_loss: 1.0835 - val_accuracy: 0.8767 - val_binary_crossentropy: 1.0835
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1527 - accuracy: 0.9876 - binary_crossentropy: 0.1527 - val_loss: 0.8212 - val_accuracy: 0.8752 - val_binary_crossentropy: 0.8212
# Epoch 13/20
# 25000/25000 - 2s - loss: 7.1722e-04 - accuracy: 0.9999 - binary_crossentropy: 7.1722e-04 - val_loss: 0.8693 - val_accuracy: 0.8774 - val_binary_crossentropy: 0.8693
# Epoch 14/20
# 25000/25000 - 2s - loss: 1.8738e-05 - accuracy: 1.0000 - binary_crossentropy: 1.8738e-05 - val_loss: 0.9543 - val_accuracy: 0.8788 - val_binary_crossentropy: 0.9543
# Epoch 15/20
# 25000/25000 - 2s - loss: 4.1602e-06 - accuracy: 1.0000 - binary_crossentropy: 4.1602e-06 - val_loss: 1.1097 - val_accuracy: 0.8787 - val_binary_crossentropy: 1.1097
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0983 - accuracy: 0.9937 - binary_crossentropy: 0.0983 - val_loss: 3.8224 - val_accuracy: 0.7407 - val_binary_crossentropy: 3.8224
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0275 - accuracy: 0.9972 - binary_crossentropy: 0.0275 - val_loss: 0.9159 - val_accuracy: 0.8778 - val_binary_crossentropy: 0.9159
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0787 - accuracy: 0.9902 - binary_crossentropy: 0.0787 - val_loss: 0.8983 - val_accuracy: 0.8547 - val_binary_crossentropy: 0.8983
# Epoch 19/20
# 25000/25000 - 2s - loss: 1.8782e-04 - accuracy: 1.0000 - binary_crossentropy: 1.8782e-04 - val_loss: 0.7995 - val_accuracy: 0.8794 - val_binary_crossentropy: 0.7995
# Epoch 20/20
# 25000/25000 - 2s - loss: 1.6901e-05 - accuracy: 1.0000 - binary_crossentropy: 1.6901e-05 - val_loss: 0.9190 - val_accuracy: 0.8786 - val_binary_crossentropy: 0.9190

# %%
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16, 10))
    
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_' + key],
                      '--', label=name.title() + " Val")
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
                 label=name.title() + " Train")
        
        plt.xlabel("Epochs")
        plt.ylabel(key.replace('_', ' ').title())
        plt.legend()
        
        plt.xlim([0, max(history.epoch)])
        
plot_history([('baseline', baseline_history),
              ('smaller', smalle_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])
l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20, batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.5073 - accuracy: 0.8171 - binary_crossentropy: 0.4661 - val_loss: 0.3724 - val_accuracy: 0.8782 - val_binary_crossentropy: 0.3288
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.2986 - accuracy: 0.9120 - binary_crossentropy: 0.2512 - val_loss: 0.3370 - val_accuracy: 0.8857 - val_binary_crossentropy: 0.2870
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.2534 - accuracy: 0.9281 - binary_crossentropy: 0.2014 - val_loss: 0.3376 - val_accuracy: 0.8865 - val_binary_crossentropy: 0.2839
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2284 - accuracy: 0.9413 - binary_crossentropy: 0.1731 - val_loss: 0.3497 - val_accuracy: 0.8822 - val_binary_crossentropy: 0.2936
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2158 - accuracy: 0.9460 - binary_crossentropy: 0.1585 - val_loss: 0.3601 - val_accuracy: 0.8794 - val_binary_crossentropy: 0.3023
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.2053 - accuracy: 0.9510 - binary_crossentropy: 0.1467 - val_loss: 0.3740 - val_accuracy: 0.8766 - val_binary_crossentropy: 0.3148
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.1978 - accuracy: 0.9540 - binary_crossentropy: 0.1378 - val_loss: 0.3901 - val_accuracy: 0.8722 - val_binary_crossentropy: 0.3297
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1929 - accuracy: 0.9560 - binary_crossentropy: 0.1317 - val_loss: 0.3999 - val_accuracy: 0.8714 - val_binary_crossentropy: 0.3383
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1860 - accuracy: 0.9595 - binary_crossentropy: 0.1240 - val_loss: 0.4098 - val_accuracy: 0.8701 - val_binary_crossentropy: 0.3475
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1827 - accuracy: 0.9599 - binary_crossentropy: 0.1200 - val_loss: 0.4220 - val_accuracy: 0.8675 - val_binary_crossentropy: 0.3591
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1765 - accuracy: 0.9625 - binary_crossentropy: 0.1132 - val_loss: 0.4350 - val_accuracy: 0.8665 - val_binary_crossentropy: 0.3715
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1745 - accuracy: 0.9622 - binary_crossentropy: 0.1103 - val_loss: 0.4517 - val_accuracy: 0.8642 - val_binary_crossentropy: 0.3873
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1701 - accuracy: 0.9638 - binary_crossentropy: 0.1051 - val_loss: 0.4673 - val_accuracy: 0.8617 - val_binary_crossentropy: 0.4021
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.1681 - accuracy: 0.9645 - binary_crossentropy: 0.1026 - val_loss: 0.4813 - val_accuracy: 0.8608 - val_binary_crossentropy: 0.4152
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.1679 - accuracy: 0.9651 - binary_crossentropy: 0.1015 - val_loss: 0.4971 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.4301
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.1638 - accuracy: 0.9659 - binary_crossentropy: 0.0965 - val_loss: 0.5045 - val_accuracy: 0.8576 - val_binary_crossentropy: 0.4372
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.1611 - accuracy: 0.9679 - binary_crossentropy: 0.0939 - val_loss: 0.5110 - val_accuracy: 0.8557 - val_binary_crossentropy: 0.4436
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.1580 - accuracy: 0.9684 - binary_crossentropy: 0.0903 - val_loss: 0.5215 - val_accuracy: 0.8565 - val_binary_crossentropy: 0.4536
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.1531 - accuracy: 0.9712 - binary_crossentropy: 0.0854 - val_loss: 0.5291 - val_accuracy: 0.8561 - val_binary_crossentropy: 0.4616
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.1525 - accuracy: 0.9704 - binary_crossentropy: 0.0846 - val_loss: 0.5403 - val_accuracy: 0.8542 - val_binary_crossentropy: 0.4722

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam', loss='binary_crossentropy',
                  metrics=['accuracy', 'binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.6070 - accuracy: 0.6532 - binary_crossentropy: 0.6070 - val_loss: 0.4630 - val_accuracy: 0.8555 - val_binary_crossentropy: 0.4630
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.4316 - accuracy: 0.8249 - binary_crossentropy: 0.4316 - val_loss: 0.3317 - val_accuracy: 0.8786 - val_binary_crossentropy: 0.3317
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.3311 - accuracy: 0.8794 - binary_crossentropy: 0.3311 - val_loss: 0.2881 - val_accuracy: 0.8862 - val_binary_crossentropy: 0.2881
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2769 - accuracy: 0.9041 - binary_crossentropy: 0.2769 - val_loss: 0.2762 - val_accuracy: 0.8877 - val_binary_crossentropy: 0.2762
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2389 - accuracy: 0.9205 - binary_crossentropy: 0.2389 - val_loss: 0.2863 - val_accuracy: 0.8876 - val_binary_crossentropy: 0.2863
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.2072 - accuracy: 0.9319 - binary_crossentropy: 0.2072 - val_loss: 0.2911 - val_accuracy: 0.8854 - val_binary_crossentropy: 0.2911
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.1839 - accuracy: 0.9404 - binary_crossentropy: 0.1839 - val_loss: 0.3068 - val_accuracy: 0.8844 - val_binary_crossentropy: 0.3068
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1609 - accuracy: 0.9468 - binary_crossentropy: 0.1609 - val_loss: 0.3257 - val_accuracy: 0.8827 - val_binary_crossentropy: 0.3257
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1449 - accuracy: 0.9514 - binary_crossentropy: 0.1449 - val_loss: 0.3475 - val_accuracy: 0.8816 - val_binary_crossentropy: 0.3475
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1319 - accuracy: 0.9552 - binary_crossentropy: 0.1319 - val_loss: 0.3620 - val_accuracy: 0.8813 - val_binary_crossentropy: 0.3620
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1166 - accuracy: 0.9602 - binary_crossentropy: 0.1166 - val_loss: 0.3976 - val_accuracy: 0.8803 - val_binary_crossentropy: 0.3976
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1087 - accuracy: 0.9606 - binary_crossentropy: 0.1087 - val_loss: 0.4097 - val_accuracy: 0.8792 - val_binary_crossentropy: 0.4097
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1011 - accuracy: 0.9646 - binary_crossentropy: 0.1011 - val_loss: 0.4471 - val_accuracy: 0.8792 - val_binary_crossentropy: 0.4471
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0961 - accuracy: 0.9648 - binary_crossentropy: 0.0961 - val_loss: 0.4436 - val_accuracy: 0.8784 - val_binary_crossentropy: 0.4436
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0900 - accuracy: 0.9664 - binary_crossentropy: 0.0900 - val_loss: 0.4450 - val_accuracy: 0.8782 - val_binary_crossentropy: 0.4450
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0835 - accuracy: 0.9680 - binary_crossentropy: 0.0835 - val_loss: 0.4816 - val_accuracy: 0.8773 - val_binary_crossentropy: 0.4816
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0774 - accuracy: 0.9712 - binary_crossentropy: 0.0774 - val_loss: 0.4962 - val_accuracy: 0.8768 - val_binary_crossentropy: 0.4962
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0767 - accuracy: 0.9696 - binary_crossentropy: 0.0767 - val_loss: 0.5425 - val_accuracy: 0.8763 - val_binary_crossentropy: 0.5425
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0729 - accuracy: 0.9711 - binary_crossentropy: 0.0729 - val_loss: 0.5345 - val_accuracy: 0.8756 - val_binary_crossentropy: 0.5345
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0683 - accuracy: 0.9730 - binary_crossentropy: 0.0683 - val_loss: 0.6029 - val_accuracy: 0.8770 - val_binary_crossentropy: 0.6029

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
