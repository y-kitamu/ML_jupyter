# %%
import numpy as np
import matplotlib.pyplot as plt

import reinforce_learning as rl
import mython

# %%
rc_client = rl.bandit.ReinforcementComparisonClient()
#rc_client.agent.sample_mean_reward[:] = 5

mython.debug.start_pdb(
    rc_client.run
)
plt.plot(rc_client.rewards)
# Out:
# 100%|██████████| 1000/1000 [00:42<00:00, 23.44it/s]

# %%
eg_client0 = rl.bandit.EpsilonGreedyClient(alpha=0.1)
eg_client1 = rl.bandit.EpsilonGreedyClient()
eg_client0.run()
eg_client1.run()

plt.plot(rc_client.rewards, label="Reinforcement Comparison")
plt.plot(eg_client0.rewards, label="Epsilon Greedy (alpha=0.1)")
plt.plot(eg_client1.rewards, label="Epsilon Greedy (alpha=1 / k)")
plt.legend()
# Out:
# ...
# 100%|██████████| 1000/1000 [00:11<00:00, 89.44it/s]

# %%
rc_client0 = rl.bandit.ReinforcementComparisonClient(init_reward=5)
rc_client1 = rl.bandit.ReinforcementComparisonClient(init_reward=-5)

rc_client0.run()
rc_client1.run()

#plt.plot(rc_client.rewards, label="initial reward = 0")
# Out:
# ...
# 100%|██████████| 1000/1000 [00:41<00:00, 24.13it/s]
# NameErrorTraceback (most recent call last)
# <ipython-input-2-0f47d453132f> in <module>
#       5 rc_client1.run()
#       6
# ----> 7 plt.plot(rc_client.rewards, label="initial reward = 0")
#       8 plt.plot(rc_client0.rewards, label="initial reward = 5")
#       9 plt.plot(rc_client1.rewards, label="initial reward = -5")
#
# NameError: name 'rc_client' is not defined

# %%
plt.plot(rc_client.rewards, label="initial reward = 0")
plt.plot(rc_client0.rewards, label="initial reward = 5")
plt.plot(rc_client1.rewards, label="initial reward = -5")
plt.legend()

# %%
pm_client = rl.bandit.PursitMethodClient()
pm_client.run()
# Out:
# 100%|██████████| 1000/1000 [00:42<00:00, 23.69it/s]

# %%
eg_client = rl.bandit.EpsilonGreedyClient()
eg_client.run()
# Out:
# 100%|██████████| 1000/1000 [00:11<00:00, 89.72it/s]

# %%
rc_client = rl.bandit.ReinforcementComparisonClient()
rc_client.run()
# Out:
# 100%|██████████| 1000/1000 [00:41<00:00, 24.10it/s]

# %%
plt.plot(pm_client.rewards, label="Pursit Method")
plt.plot(eg_client.rewards, label="epsilon greedy")
plt.plot(rc_client.rewards, label="Reinforcement Comparison")
plt.legend()
